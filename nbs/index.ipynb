# %% [raw]
# ---
# title: ""
# page-layout: full
# ---

# %% [markdown]
# <div class="hero">
# <span class="fly-deco" style="top:12%;left:8%">🪰</span>
# <span class="fly-deco" style="top:22%;right:12%">🪰</span>
# <span class="fly-deco" style="bottom:20%;left:18%">🪰</span>
# <div class="hero-inner">
# <img src="images/headshot.jpg" class="headshot" alt="Sangyu Xu">
# <div class="hero-name">Sangyu Xu</div>
# <span class="hero-chinese">徐桑榆</span>
# <p class="hero-tagline">Computational Behaviour Scientist</p>
# <a href="cv.html" style="display:inline-block;margin-bottom:1rem;font-size:0.85rem;font-weight:600;letter-spacing:0.04em;color:#b8954a;text-decoration:none;">Read my CV &rarr;</a>
# <div class="hero-badges">
# <a href="neuroscience.html" class="badge-link">
#   <span class="hero-badge">🪰Animal Behaviour🐭</span>
# </a>
# <a href="statistics.html" class="badge-link">
#     <span class="hero-badge">
#     <img src="https://www.estimationstats.com/static/dist/img/Box.baa1019b.svg" class="badge-icon" alt="Box icon">
#     Effect size Estimation
#     </span>
# </a>
# <a href="art.html" class="badge-link">
#     <span class="hero-badge">🎨Art🎵</span>
# </a>
# </div>
# </div>
# </div>

# %% [markdown]
# <div class="about-section">
# <p>
# I'm a computational behavior scientist with 15+ years building tools that model complex, ambiguous systems. I am currently a Senior Research Fellow at the <a href="https://www.claridgechang.net/about.html" target="_blank">Adam Claridge-Chang Lab</a>.
# </p>
# </div>

# %% [markdown]
# <div class="news-section">
# <h2 class="news-title">Recent</h2>
# <ul class="news-list">
#   <li><span class="news-date">Jul 2026</span> <a href="https://doi.org/10.64898/2026.07.01.735755" target="_blank">Ethomics paper</a> posted to bioRxiv.</li>
#   <li><span class="news-date">Apr 2026</span> <a href="https://www.biorxiv.org/content/10.64898/2026.04.12.718060v1" target="_blank">LSSmScarlet3 paper</a> posted to bioRxiv.</li>
#   <li><span class="news-date">Mar 2026</span> <a href="https://www.biorxiv.org/content/10.64898/2026.03.13.711740v1" target="_blank">Octopamine-driven feeding paper</a> posted to bioRxiv.</li>
#   <li><span class="news-date">Jan 2026</span> <a href="https://www.biorxiv.org/content/10.64898/2026.01.26.701654v2" target="_blank">DABEST 2.0 paper</a> posted to bioRxiv.</li>
# </ul>
# </div>

# %% [markdown]
# <div class="featured-story">
# <img src="images/blog/ethomics_phenovectors.png" class="featured-story-img" alt="Clustering ethomics phenovectors — similar whole-behavior profiles cluster together">
# <div class="featured-story-body">
# <p class="featured-story-label">Hot Off the Press &middot; Neuroscience &middot; Methods</p>
# <p class="featured-story-title">What Is a Hungry Fly?</p>
# <p class="featured-story-desc">Hunger and satiety are not single behaviors — they are coordinated internal states, expressed across many dimensions at once. On tracking thousands of <em>Drosophila</em> to understand how serotonin implements hunger, and what it takes to prove a neural manipulation actually changed the state rather than just one metric.</p>
# <a class="featured-story-link" href="blog/02_ethomics.html">&rarr; Read the essay</a> &ensp; <a class="featured-story-link" href="https://doi.org/10.64898/2026.07.01.735755" target="_blank">bioRxiv &nearr;</a>
# </div>
# </div>

# %% [markdown]
# <div class="section-divider">&bull; &bull; &bull;</div>
# <div class="cards-grid">
# <div class="feature-card">
# <img src="https://www.estimationstats.com/static/dist/img/Box.baa1019b.svg" class="card-icon-svg" alt="DABEST estimation graphic">
# <h3 class="card-title">Getting Over ANOVA</h3>
# <p class="card-text">
# DABEST2 &mdash; a framework that replaces p-values with bootstrap confidence intervals and effect size estimation for multiplex comparisons, following the 2,000+ citations predecessor DABEST. Binary significance testing gives you vibes. Estimation gives you evidence.
# </p>
# <a class="card-link" href="blog/01_dabest.html">&rarr; Read more</a> &ensp; <a class="card-link" href="dabest_demo.html">Demo &nearr;</a>
# </div>
# <div class="feature-card">
# <span class="card-icon">🪰</span>
# <h3 class="card-title">What Is a Hungry Fly?</h3>
# <p class="card-text">
# Tracking thousands of <em class="species">Drosophila</em> across millions of frames to understand how
# serotonin implements hunger states. Custom hardware, computer vision, 17 behavioural metrics, high-dimensional statistics. The question: how do you know if a
# manipulation actually changed the state, or just one metric?
# </p>
# <a class="card-link" href="blog/02_ethomics.html">&rarr; Read more</a>
# </div>
# <div class="feature-card">
# <span class="card-icon">🤖</span>
# <h3 class="card-title">Four Agents, No Ground Truth</h3>
# <p class="card-text">
# A biologist, a bioinformatician, a reviewer, and an editor &mdash; all LLMs, arguing
# about a manuscript. The easy part was building it. The hard part: how do you know it's accurate? how much does a human have to sit on the loop?
# </p>
# <a class="card-link" href="https://github.com/sangyu/lanting" target="_blank">Lanting on GitHub &nearr;</a>
# </div>
# </div>
